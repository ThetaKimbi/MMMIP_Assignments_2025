# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.signal import convolve

# %% [markdown]
# Local Polynomial Approximation
# -------------------------------
# Set the parameters

# %%
# maximum degree of polynomial used for fitting
N = 2

# filter size
M = 51

# large M, small N -> a lot of bias when frequency increases
# N = 2
# M = 51

# large M, large N -> smaller bias than before, but a lot of variance in smooth regions
# N = 7
# M = 51

# small M, small N -> smaller bias everywhere, higher variance
# N = 2
# M = 5

# M small, M = N,  -> smaller bias than before, higher variance than before
# N = 5
# N = M

# %% [markdown]
# Generate synthetic signal signal

# %%
LENGHT = 1000

ty = np.linspace(0, 1, LENGHT)
y = np.sin(2 / (ty + 0.05))

#  noise standard deviation
sigma = 0.1

# noisy signal
s = y + sigma*np.random.normal(size=LENGHT)

# %%
plt.figure()
plt.plot(ty, s, 'r.')
plt.plot(ty, y, 'k--', linewidth=2)
plt.grid()
plt.legend(['noisy', 'original'])
plt.title('Input Signal')
# Out:
# Text(0.5, 1.0, 'Input Signal')

# %% [markdown]
# Define the matrix T containing the polynomials sampled over the window

# %% [markdown]
# t represents the sampling points over which a polynomial basis is evaluated. They are independent variable values at which to approximate and create a linarly spaced array of M points between 0 and +1

# %%
t = np.linspace(0, 1, M)
T = np.vander(t, N+1, increasing=True)

# %% [markdown]
# Look at the matrix T, the columns correspond to polynomials sampled over the interval [0,1]

# %%
plt.figure()
leg = []
for l in range(N+1):
    plt.plot(t, T[:, l])
    leg.append(f't^{l:d}')
plt.legend(leg)

# %% [markdown]
# Construct the LPA kernel

# %%
# comput the qr decomposition of WT
# since T has more rows than columns, then qr computes only the first N + 1 columns of Q and the first N + 1 rows of R.
Q, R = np.linalg.qr(T)
print(Q.shape)
print(R.shape)

# select the central row of W2Qtilde
central_row_index = int(Q.shape[0]/2)
row = Q[central_row_index, :]

# compute the kernel
g = sum([row[i]*Q[:,i] for i in range(N+1)])

# flipping, since it is used in convolution
g = np.flip(g)
# Out:
# (51, 3)
# (3, 3)

# %%
plt.figure()
plt.plot(g, 'rs', linewidth=3)
plt.title(f'M = {M:d}, N = {N:d}')
# Out:
# Text(0.5, 1.0, 'M = 51, N = 2')

# %% [markdown]
# Filtering

# %%
shat = convolve(s, g, mode='same')

# %%
plt.figure(figsize=(10,10))
plt.plot(ty, s, 'r.')
plt.plot(ty, y, 'k--', linewidth=3)
plt.plot(ty, shat, 'm-', linewidth=3)
plt.grid()
plt.legend(['noisy', 'original', 'LPA estimate'])
plt.title(f'M = {M:d}, N = {N:d}')
# Out:
# Text(0.5, 1.0, 'M = 51, N = 2')

# %% [markdown]
# Weighted LPA
# --------------
# Set the parameters

# %%
# maximum degree of polynomial used for fitting
N = 1

# filter size
M = 53

# half filter size
HFS = int((M-1)/2)

# set the weights. Here weights simply define the window size
w = np.zeros(M)

# centered kernel
wc = w.copy()
wc[int(HFS/2):-int(HFS/2)] = 1

# left kernel
wl = w.copy()
wl[:HFS+1] = 1

# right kernel
wr = w.copy()
wr[-HFS-1:] = 1

# %%
fig, ax = plt.subplots(3, 1, figsize=(10,10))
ax[0].plot(wc, 'rs', linewidth=3)
ax[0].set_title('centered weights')
ax[0].grid()
ax[1].plot(wl, 'bs', linewidth=3)
ax[1].set_title('left weights')
ax[1].grid()
ax[2].plot(wr, 'ms', linewidth=3)
ax[2].set_title('right weights')
ax[2].grid()

# %% [markdown]
# Build the weight matrix

# %%
# select a single weight to be used in what follows
w = wc

# generate the inverse of weights
winv = 1/w

# set to zero weights that are inf
winv = np.where(np.isinf(winv), 0, winv)

# define the weight matrix
W = np.diag(w)
Winv = np.diag(winv)
# Out:
# /tmp/ipython-input-4036357651.py:5: RuntimeWarning: divide by zero encountered in divide
#   winv = 1/w

# %% [markdown]
# Generate synthetic signal signal

# %%
LENGHT = 1000

# clean signal
ty = np.linspace(0, 1, LENGHT)
y =  8*ty**2 - 2*ty + 2;
y[LENGHT//2 : LENGHT] = y[LENGHT//2 : LENGHT] + 7;

#  noise standard deviation
sigma = 0.2

# noisy signal
s = y + sigma*np.random.normal(size=LENGHT)

# %%
plt.figure()
plt.plot(ty, s, 'r.')
plt.plot(ty, y, 'k--', linewidth=2)
plt.grid()
plt.legend(['noisy', 'original'])
plt.title('Input Signal')
# Out:
# Text(0.5, 1.0, 'Input Signal')

# %% [markdown]
# Define the matrix T containing the polynomials sampled over the window

# %%
t = np.linspace(0, 1, M)
T = np.vander(t, N+1, increasing=True)

# %% [markdown]
# Construct the LPA kernel

# %%
# comput the qr decomposition of WT
# since T has more rows than columns, then qr computes only the first N + 1 columns of Q and the first N + 1 rows of R.
Q, R =  np.linalg.qr(np.dot(W, T))

#  define Qtilde
Qtilde = np.dot(Winv, Q)

# adjust Qtilde with the  weights matrix squared.
W2Qtilde = np.dot(W**2, Qtilde)

# select the central row of W2Qtilde
central_row_index = int(Qtilde.shape[0]/2)
row = Qtilde[central_row_index, :]

# compute the kernel
g = sum([row[i]*Q[:,i] for i in range(N+1)])

# flipping, since it is used in convolution
g = np.flip(g)

# %%
plt.figure()
plt.plot(g, 'rs', linewidth=3)
plt.title(f'filter M = {M:d}, N = {N:d}')
# Out:
# Text(0.5, 1.0, 'filter M = 53, N = 1')

# %% [markdown]
# Filtering

# %%
shat =  convolve(s, g, mode='same')

# %%
plt.figure()
plt.plot(ty, s, 'r.')
plt.plot(ty, y, 'k--', linewidth=3)
plt.plot(ty, shat, 'm-', linewidth=3)
plt.grid()
plt.legend(['noisy', 'original', 'LPA estimate'])
plt.title(f'M = {M:d}, N = {N:d}')
# Out:
# Text(0.5, 1.0, 'M = 53, N = 1')

# %% [markdown]
# Modify the code to use the central, left and right kernels

# %%
def show_aprroximation(ty, y, s, shat, M, N):
  plt.figure()
  plt.plot(ty, s, 'r.')
  plt.plot(ty, y, 'k--', linewidth=3)
  plt.plot(ty, shat, 'm-', linewidth=3)
  plt.grid()
  plt.legend(['noisy', 'original', 'LPA estimate'])
  plt.title(f'M = {M:d}, N = {N:d}')

# %%
def weighted_lpa(polynomial_degree, filter_size, weights, signal, show=True):
  # select a single weight to be used in what follows
  w = weights

  # generate the inverse of weights
  winv = 1/w

  # set to zero weights that are inf
  winv = np.where(np.isinf(winv), 0, winv)

  # define the weight matrix
  W = np.diag(w)
  Winv = np.diag(winv)

  # define the matrix T containing the polynomials sampled over the window
  t = np.linspace(0, 1, M)
  T = np.vander(t, N+1, increasing=True)

  # comput the qr decomposition of WT
  # since T has more rows than columns, then qr computes only the first N + 1 columns of Q and the first N + 1 rows of R.
  Q, R = np.linalg.qr(np.dot(W, T))
  print(Q.shape)

  #  define Qtilde
  Qtilde = np.dot(Winv, Q)

  # adjust Qtilde with the  weights matrix squared.
  W2Qtilde = np.dot(W**2 ,Qtilde)

  # select the central row of W2Qtilde
  central_row_index = int(W2Qtilde.shape[0]/2)
  row = W2Qtilde[central_row_index, :]

  # compute the kernel
  g = sum([row[i]* Q[:, i] for i in range(N+1)])

  # flipping, since it is used in convolution
  g =  np.flip(g)

  shat = convolve(s, g, mode='same')

  return shat

# %%
rightEstimate = weighted_lpa(N, M, wr, s)
leftEstimate = weighted_lpa(N, M, wl, s)
# Out:
# (53, 2)
# (53, 2)
# /tmp/ipython-input-1783372406.py:6: RuntimeWarning: divide by zero encountered in divide
#   winv = 1/w

# %%
show_aprroximation(ty, y, s, rightEstimate, M, N)
show_aprroximation(ty, y, s, leftEstimate, M, N)
